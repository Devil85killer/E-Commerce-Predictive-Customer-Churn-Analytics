# %%
import pandas as pd
import numpy as np
import urllib

from sqlalchemy import create_engine

print("Libraries loaded!")
# Out:
# Libraries loaded!

# %%
server = r"DEVIL\SQLEXPRESS"
database = "ecommerce"

params = urllib.parse.quote_plus(
    f"DRIVER={{ODBC Driver 17 for SQL Server}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"Trusted_Connection=yes;"
)

engine = create_engine(
    "mssql+pyodbc:///?odbc_connect=" + params,
    pool_pre_ping=True
)

print("Connected!")
# Out:
# Connected!

# %%
df = pd.read_sql(
    """
    SELECT *
    FROM dbo.Customer_Churn_ML
    """,
    engine
)

print("Dataset Shape:", df.shape)

df.head()
# Out:
# c:\Users\sahuj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:1649: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())
# Dataset Shape: (55906, 7)
#                  customer_unique_id  recency  frequency    monetary  \
# 0  0000f46a3911fa3c0805444483337064      357          1   86.220001
# 1  0000f6ccb0745a6a4b88665a16c9f078      141          1   43.619999
# 2  0004aac84e0df4da2b147fca70cf8255      108          1  196.889999
# 3  00053a61a98854899e70ed204dd4bafe        2          1  419.179993
# 4  0005e1862207bf6ccc02e4228effd9a0      363          1  150.119995
#
#    avg_order_value  customer_lifetime_days  churn_target
# 0        86.220001                       0             1
# 1        43.619999                       0             1
# 2       196.889999                       0             1
# 3       419.179993                       0             1
# 4       150.119995                       0             1

# %%
print(df.columns.tolist())
print(
    df["churn_target"].value_counts(
        dropna=False
    )
)
print(
    df["churn_target"]
    .value_counts(
        normalize=True,
        dropna=False
    ) * 100
)
# Out:
# ['customer_unique_id', 'recency', 'frequency', 'monetary', 'avg_order_value', 'customer_lifetime_days', 'churn_target']
# churn_target
# 1    55251
# 0      655
# Name: count, dtype: int64
# churn_target
# 1    98.828391
# 0     1.171609
# Name: proportion, dtype: float64
